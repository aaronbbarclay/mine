# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronbbarclay/mine/blob/master/Copy_of_contact_sheet_v03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !mkdir -p /content/local_drive/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Documents/ContactSheet/src/concept1_in
# %ls
# %cd /content/local_drive/concept1_in/ramsgate_01
# %ls
# Out:
# /content/drive/My Drive/Documents/ContactSheet/src/concept1_in
# A/  all/  B/  C/  ramsgate_01/  ramsgate_01_linear/
# /content/local_drive/concept1_in/ramsgate_01
# IMG_3091.jpg  IMG_3130.jpg  IMG_3169.jpg  IMG_3208.jpg  IMG_3247.jpg
# IMG_3092.jpg  IMG_3131.jpg  IMG_3170.jpg  IMG_3209.jpg  IMG_3248.jpg
# IMG_3093.jpg  IMG_3132.jpg  IMG_3171.jpg  IMG_3210.jpg  IMG_3249.jpg
# IMG_3094.jpg  IMG_3133.jpg  IMG_3172.jpg  IMG_3211.jpg  IMG_3250.jpg
# IMG_3095.jpg  IMG_3134.jpg  IMG_3173.jpg  IMG_3212.jpg  IMG_3251.jpg
# IMG_3096.jpg  IMG_3135.jpg  IMG_3174.jpg  IMG_3213.jpg  IMG_3252.jpg
# IMG_3097.jpg  IMG_3136.jpg  IMG_3175.jpg  IMG_3214.jpg  IMG_3253.jpg
# IMG_3098.jpg  IMG_3137.jpg  IMG_3176.jpg  IMG_3215.jpg  IMG_3254.jpg
# IMG_3099.jpg  IMG_3138.jpg  IMG_3177.jpg  IMG_3216.jpg  IMG_3255.jpg
# IMG_3100.jpg  IMG_3139.jpg  IMG_3178.jpg  IMG_3217.jpg  IMG_3256.jpg
# IMG_3101.jpg  IMG_3140.jpg  IMG_3179.jpg  IMG_3218.jpg  IMG_3257.jpg
# ...

# %%
# !apt search openimageio
#!apt-get install libopenimageio1.7
# !apt-get install openimageio-tools
# !apt-get install python-openimageio

# %%
# %cd /content/local_drive/concept1_in/
# !mkdir -p ramsgate_01_linear/
# %ls
# Out:
# /content/local_drive/concept1_in
# all/  ramsgate_01/  ramsgate_01_linear/

# %%
# %cd /content/
# !git clone https://github.com/colour-science/OpenColorIO-Configs/
# Out:
# /content
# Cloning into 'OpenColorIO-Configs'...
# remote: Enumerating objects: 3739, done.
# remote: Total 3739 (delta 0), reused 0 (delta 0), pack-reused 3739
# Receiving objects: 100% (3739/3739), 1.43 GiB | 21.72 MiB/s, done.
# Resolving deltas: 100% (1578/1578), done.
# Checking out files: 100% (1206/1206), done.

# %%
# !export OCIO=/content/OpenColorIO-Configs/aces_1.0.3/config.ocio
# !oiiotool --help --colorconfig /content/OpenColorIO-Configs/aces_1.0.3/config.ocio

# %%
# Convert to linear
print("#"*80)
print("Processing everything in ALL or RAMSGATE_01")
print("#"*80)

inPath = r"/content/local_drive/concept1_in/ramsgate_01"
outPath2 = r"/content/local_drive/concept1_in/ramsgate_01_linear"

#inPath = r"/content/local_drive/concept1_in/all"
#outPath2 = r"/content/local_drive/concept1_out"

print("inpath: {0}".format(inPath))
print("outpath: {0}".format(outPath2))

if os.path.isdir(outPath2):
    pass
else:
    os.makedirs(outPath2)

ROOT_DIR = os.path.abspath(inPath)
files = os.listdir(inPath)

images = []
WIDTH = 3000
HEIGHT = 2500

images = []
NUMBER_OF_IMG = 0
result = None

REPEAT_MODE = 25
REPEATS = 45
#Known color spaces: "linear", "sRGB", "Rec709"
START_FILE = None
OUT_FILE = "/content/local_drive/concept1_in/ramsgate_01_tmp_v100.exr"
FINAL_FILE = "/content/local_drive/concept1_in/ramsgate_01_v100.exr"
FILECOUNT = 0
for x, fileName in enumerate(os.listdir(inPath)):
    filePath = os.path.join(inPath, fileName)
 
    assert os.path.isfile(filePath)
    out_filename = fileName.replace(".jpg", ".exr")
    out_filepath = os.path.join(outPath2, out_filename)
    print(out_filename)
    #img = cv2.imread(filePath)
    #!oiiotool --colorconfig /content/OpenColorIO-Configs/aces_1.0.3/config.ocio -i $filePath --iscolorspace "Input - Generic - sRGB - Texture" --tocolorspace "ACES - ACEScg" --autoorient -o /content/local_drive/concept1_in/ramsgate_01_linear/$out_filename -d half --compression zip32
    # !oiiotool -i $filePath --powc 2.2 --rotate180 -d half --compression zip32 -o $out_filepath
    #!cp /content/local_drive/concept1_in/ramsgate_01_linear/$out_filename /content/drive/My\ Drive/Documents/ContactSheet/src/concept1_in/ramsgate_01_linear/$out_filename
    print("PART_B")
    if not START_FILE:
        START_FILE = out_filepath
        # !oiiotool $START_FILE $out_filepath --add -o $OUT_FILE
    else:
        # !oiiotool $out_filepath $OUT_FILE --add -o $OUT_FILE
        FILECOUNT += 1

# !oiiotool $OUT_FILE --divc $FILECOUNT -o $FINAL_FILE
# !cp $FINAL_FILE /content/drive/My\ Drive/Documents/ContactSheet/src/concept1_in/
print(FINAL_FILE)
# Out:
# ################################################################################
# Processing everything in ALL or RAMSGATE_01
# ################################################################################
# inpath: /content/local_drive/concept1_in/ramsgate_01
# outpath: /content/local_drive/concept1_in/ramsgate_01_linear
# IMG_3110.exr
# didn't know how to process Exif:SubjectArea, type 3 x 4
# didn't know how to process Exif:SubjectArea, type 3 x 4
# OIIO DEBUG: Don't know what to do with float[4] Exif:LensSpecification
# OIIO DEBUG: Don't know what to do with uint8[548] ICCProfile
# PART_B
# IMG_3176.exr
# didn't know how to process Exif:SubjectArea, type 3 x 4
# didn't know how to process Exif:SubjectArea, type 3 x 4
# OIIO DEBUG: Don't know what to do with float[4] Exif:LensSpecification
# OIIO DEBUG: Don't know what to do with uint8[548] ICCProfile
# PART_B
# IMG_3269.exr
# didn't know how to process Exif:SubjectArea, type 3 x 4
# ...

# %%
# %cd /content/drive/My\ Drive/Documents/ContactSheet/src
# %ls
# !mkdir -p /content/local_drive/concept1_in/
# !cp -r /content/drive/My\ Drive/Documents/ContactSheet/src/concept1_in/all /content/local_drive/concept1_in/
# !cp -r /content/drive/My\ Drive/Documents/ContactSheet/src/concept1_in/ramsgate_01 /content/local_drive/concept1_in/
# %ls
# Out:
# /content/drive/My Drive/Documents/ContactSheet/src
# A_concept.jpg                    kogorah_1_f6.jpg
# ALL_f6.jpg                       ramsgate_01_f6_135-images.jpg
# B_concept.jpg                    ramsgate_01_f6_189-images_15-25.jpg
# blurry_1a_f6.jpg                 ramsgate_01_f6_189-images_20-35.jpg
# C_concept.jpg                    ramsgate_01_f6_189-images_24-45.jpg
# concept1/                        ramsgate_01_f6_189-images_25-12.jpg
# concept1_in/                     ramsgate_01_f6_189-images_40-25.jpg
# concrete_1a_f6.jpg               ramsgate_01_f6_189-images_40-8.jpg
# concrete_experiment_v100_f6.jpg  ramsgate_01_f6_189-images_45-18.jpg
# concrete_f6.jpg                  ramsgate_01_f6_189-images_45-25.jpg
# f6Monteray/                      ramsgate_01_f6_189-images_45-30.jpg
# gymea_1_f6.jpg                   ramsgate_01_f6_189-images_7-7.jpg
# gymea_2_f6.jpg                   ramsgate_01_f6_30-images.jpg
# kogorah_1a_f6.jpg                ramsgate_10a_f6.jpg
# ...

# %%
# %cd /content/local_drive/concept1_in/ramsgate_01//
#%cd /content/local_drive/f6Monteray/fft_1
# %ls |sort
# %ls |wc

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pylab
import os.path

# %%
path = r"/content/local_drive/concept1_in/all"
if os.path.isdir(path):
    print(path)
    
    dirs = os.listdir(path)
    print(dirs)
    for d in dirs:
        dir_path = os.path.join(path, d)
        files = os.listdir(dir_path)
        for f in files:
            full_path = os.path.join(dir_path, f)
            print(full_path)

# %%
imgList = [
    #["gymea_1", "", ["_DSC3449.jpg", "_DSC3440.jpg", "_DSC3446.jpg", "_DSC3444.jpg", "_DSC3445.jpg", "_DSC3443.jpg", "_DSC3442.jpg"]],
    #["gymea_2", "", ["_DSC8133.jpg", "_DSC8144.jpg","_DSC3449.jpg", "_DSC3440.jpg", "_DSC3413.jpg", "_DSC3414.jpg", "_DSC3416.jpg", "_DSC3417.jpg", "_DSC3417-2.jpg", "_DSC3418.jpg", "_DSC3418-2.jpg", "_DSC3419.jpg", "_DSC3420.jpg", "_DSC3421.jpg", "_DSC3423.jpg", "_DSC3424.jpg", "_DSC3425-2.jpg", "_DSC3427.jpg", "_DSC3428.jpg", "_DSC3429.jpg", "_DSC3430.jpg", "_DSC3431.jpg", "_DSC3432.jpg", "_DSC3433.jpg", "_DSC3435.jpg", "_DSC3436.jpg", "_DSC3437.jpg", "_DSC3438.jpg", "_DSC3439.jpg", "_DSC3446.jpg", "_DSC3444.jpg", "_DSC3445.jpg", "_DSC3443.jpg", "_DSC3442.jpg", "_DSC3447.jpg", "_DSC3448.jpg", "_DSC3449-2.jpg", "_DSC3452.jpg"]],
    #["xxx", "", ["_DSC4127.jpg", "_DSC4122.jpg"]],
    #["kogorah_1a", "", ["_DSC4092.jpg", "_DSC4093.jpg", "_DSC4094-2.jpg", "_DSC4095.jpg", "_DSC4095-2.jpg", "_DSC4096.jpg", "_DSC4097-2.jpg", "_DSC4098.jpg", "_DSC4099.jpg", "_DSC4100.jpg", "_DSC4101.jpg", "_DSC4102.jpg", "_DSC4103.jpg", "_DSC4104.jpg", "_DSC4105.jpg", "_DSC4107.jpg", "_DSC4110.jpg", "_DSC4111.jpg", "_DSC4112.jpg", "_DSC4115.jpg", "_DSC4116.jpg", "_DSC4122-2.jpg", "_DSC4123.jpg", "_DSC4127.jpg", "_DSC6897.jpg", "_DSC6897.jpg", "_DSC6899.jpg", "_DSC6900.jpg", "_DSC6902.jpg", "_DSC6903.jpg", "_DSC6906.jpg", "_DSC6909.jpg","_DSC6910.jpg", "_DSC6911.jpg", "_DSC6912.jpg", "_DSC6913.jpg", "_DSC6914.jpg", "_DSC6917.jpg",]],
    #["kogorah_1b", "", ["_DSC4092.jpg", "_DSC4093.jpg", "_DSC4094-2.jpg", "_DSC4095.jpg", "_DSC4095-2.jpg", "_DSC4096.jpg", "_DSC4097-2.jpg", "_DSC4098.jpg", "_DSC4099.jpg", "_DSC4100.jpg", "_DSC4101.jpg", "_DSC4102.jpg", "_DSC4103.jpg", "_DSC4104.jpg", "_DSC4105.jpg", "_DSC4107.jpg", "_DSC4110.jpg", "_DSC4111.jpg", "_DSC4112.jpg", "_DSC4115.jpg", "_DSC4116.jpg", "_DSC4122-2.jpg", "_DSC4123.jpg", "_DSC4127.jpg", "_DSC6897.jpg", "_DSC6897.jpg", "_DSC6899.jpg", "_DSC6900.jpg", "_DSC6902.jpg", "_DSC6903.jpg"]],
    #["ramsgate_1a", "", ["_DSC8019.jpg", "_DSC8030.jpg", "_DSC8033.jpg", "_DSC8038.jpg", "_DSC8056.jpg", "_DSC8058.jpg", "_DSC8060.jpg", "_DSC8062.jpg", "_DSC8063.jpg", "_DSC8064.jpg", "_DSC8067.jpg", "_DSC8068.jpg", "_DSC8069.jpg", "_DSC8070.jpg", "_DSC8198.jpg", "_DSC8201.jpg", "_DSC8208.jpg", "_DSC8213.jpg", "_DSC8445.jpg", "_DSC8446.jpg", "_DSC8447.jpg", "_DSC8448.jpg", "_DSC8449.jpg", "_DSC8454.jpg", "_DSC8457.jpg", "_DSC8457.jpg", "_DSC8458.jpg", "_DSC8464.jpg", "_DSC8466.jpg", "_DSC8468.jpg", "_DSC8469.jpg", "_DSC8472.jpg",]],
    #["blurry_1a", "", ["_DSC7111.jpg", "_DSC7112.jpg", "_DSC7113.jpg", "_DSC7114.jpg", "_DSC7115.jpg", "_DSC7118.jpg", "_DSC7119.jpg", "_DSC7120.jpg", "_DSC7126.jpg", "_DSC7129.jpg", "_DSC7136.jpg", "_DSC7140.jpg", "_DSC7143.jpg", "_DSC7148.jpg", "_DSC7155.jpg", "_DSC7158.jpg", "_DSC7160.jpg", "_DSC7161.jpg", "_DSC7170.jpg", "_DSC7171.jpg", "_DSC7172.jpg", "_DSC7181.jpg", "_DSC7181.jpg", "_DSC7182.jpg", "_DSC7989.jpg", "_DSC7990.jpg", "_DSC7991.jpg", "_DSC7992.jpg", "_DSC7993.jpg", "_DSC7999.jpg", "_DSC8000.jpg", "_DSC8001.jpg", "_DSC8002.jpg", "_DSC8010.jpg", "_DSC8011.jpg", "_DSC8015.jpg", "_DSC8049.jpg", "_DSC8050.jpg", "_DSC8051.jpg", "_DSC8052.jpg", "_DSC8056.jpg", "_DSC8060.jpg",]],
    #["concrete", "", ["_DSC8071.jpg", "_DSC8072.jpg", "_DSC8073.jpg", "_DSC8074.jpg", "_DSC8075.jpg", "_DSC8076.jpg", "_DSC8077.jpg", "_DSC8078.jpg", "_DSC8079.jpg", "_DSC8080.jpg", "_DSC8081.jpg", "_DSC8082.jpg", "_DSC8089.jpg", "_DSC8208.jpg", "_DSC8213.jpg",]],
    #["concrete_1a", "", ["_DSC8071.jpg", "_DSC8072.jpg", "_DSC8073.jpg", "_DSC8074.jpg", "_DSC8075.jpg", "_DSC8076.jpg", "_DSC8077.jpg", "_DSC8078.jpg", "_DSC8079.jpg", "_DSC8080.jpg", "_DSC8081.jpg", "_DSC8082.jpg", "_DSC8089.jpg", "_DSC8208.jpg", "_DSC8213.jpg", "_DSC8443.jpg",]],
    ["ramsgate_10a", "ramsgate_01", ["IMG_3091.jpg", "IMG_3092.jpg", "IMG_3093.jpg", "IMG_3098.jpg", "IMG_3099.jpg", "IMG_3091.jpg", "IMG_3101.jpg", "IMG_3102.jpg", "IMG_3102.jpg",]],
]
    

for x in imgList:
    l = len(x[2])
    s = set(x[2])
    ls = len(s)
    print("{name}: {length} set length: {setLength}".format(name=x[0], length=l, setLength=ls))

    prefix = x[1]
    if not prefix:
        prefix = "all"

    inPath = r"/content/local_drive/concept1_in/{0}".format(prefix)

    for i in x[2]:
        filePath = os.path.join(inPath, i)
        if not os.path.isfile(filePath):
            print("Not a file: {0}".format(filePath))
# Out:
# ramsgate_10a: 9 set length: 7

# %%
# Selected creation


inPath = r"/content/local_drive/concept1_in/"
outPath2 = r"/content/local_drive/concept1_out"

print("inpath: {0}".format(inPath))
print("outpath: {0}".format(outPath2))

REPEAT_MODE = 3
REPEATS = 5

if os.path.isdir(outPath2):
    pass
else:
    os.makedirs(outPath2)

ROOT_DIR = os.path.abspath(inPath)
files = os.listdir(inPath)

images = []
WIDTH = 3000
HEIGHT = 2500

for x, _img in enumerate(imgList):
    name = _img[0]
    images = []
    print(name)
    prefix = _img[1]
    if not prefix:
        prefix = "all"

    for fileName in _img[2]:
        filePath = os.path.join(inPath, prefix, fileName)
        print(filePath)
        assert os.path.isfile(filePath)
        img = cv2.imread(filePath)
        #print(img.shape)

        #if (img.shape[0] < HEIGHT) or (img.shape[1] < WIDTH):
        #    print("WRONG")
        #    continue

        #else:
        cropped = img[0:WIDTH, 0:HEIGHT]
        resized = cv2.resize(img, (WIDTH, HEIGHT), interpolation=cv2.INTER_AREA)
        img2 = resized.astype(np.float32)
        print("Appending: {0} {1} {2}".format(fileName, img2.shape[0], img2.shape[1]))
        images.append(img2)

    NUMBER_OF_IMG = len(images)
    print("number of img", NUMBER_OF_IMG)
    r2 = NUMBER_OF_IMG * np.ones(shape=images[0].shape, dtype=np.float32)
    result = np.zeros(shape=images[0].shape, dtype=np.float32)

    for j, i in enumerate(images):    
        #print(r2.shape)
        #print(result.shape)
        r = result
        #print(i.shape)
        #print(r.shape)
        if j % REPEAT_MODE == 0:
            print("REPEATS")
            for n in range(REPEATS):
                result = cv2.add(r, i)

        result = cv2.add(r, i)

    finalResult = cv2.divide(result, r2)
    imgPath = outPath2 + "/{0}_f6.jpg".format(name)
    fImg = finalResult.astype(np.uint8)
    print(imgPath)
    cv2.imwrite(imgPath, fImg)

    # !cp $imgPath /content/drive/My\ Drive/Documents/ContactSheet/src/
# Out:
# inpath: /content/local_drive/concept1_in/
# outpath: /content/local_drive/concept1_out
# ramsgate_10a
# /content/local_drive/concept1_in/ramsgate_01/IMG_3091.jpg
# Appending: IMG_3091.jpg 2500 3000
# /content/local_drive/concept1_in/ramsgate_01/IMG_3092.jpg
# Appending: IMG_3092.jpg 2500 3000
# /content/local_drive/concept1_in/ramsgate_01/IMG_3093.jpg
# Appending: IMG_3093.jpg 2500 3000
# /content/local_drive/concept1_in/ramsgate_01/IMG_3098.jpg
# Appending: IMG_3098.jpg 2500 3000
# /content/local_drive/concept1_in/ramsgate_01/IMG_3099.jpg
# Appending: IMG_3099.jpg 2500 3000
# /content/local_drive/concept1_in/ramsgate_01/IMG_3091.jpg
# Appending: IMG_3091.jpg 2500 3000
# number of img 6
# REPEATS
# REPEATS
# /content/local_drive/concept1_out/ramsgate_10a_f6.jpg

# %%
10 % 10
# Out:
# 0

# %%
# Everything in ALL OR ramsgate_01
print("#"*80)
print("Processing everything in ALL or RAMSGATE_01")
print("#"*80)

inPath = r"/content/local_drive/concept1_in/ramsgate_01"
outPath2 = r"/content/local_drive/concept1_out"

#inPath = r"/content/local_drive/concept1_in/all"
#outPath2 = r"/content/local_drive/concept1_out"

print("inpath: {0}".format(inPath))
print("outpath: {0}".format(outPath2))

if os.path.isdir(outPath2):
    pass
else:
    os.makedirs(outPath2)

ROOT_DIR = os.path.abspath(inPath)
files = os.listdir(inPath)

images = []
WIDTH = 3000
HEIGHT = 2500

images = []
NUMBER_OF_IMG = 0
result = None

REPEAT_MODE = 25
REPEATS = 45

for x, fileName in enumerate(os.listdir(inPath)):
    filePath = os.path.join(inPath, fileName)
 
    assert os.path.isfile(filePath)
    img = cv2.imread(filePath)

    if img.shape[0] == 3024:
        #resized = cv2.resize(img, (WIDTH, HEIGHT), interpolation=cv2.INTER_AREA)
        img2 = img.astype(np.float32)
        print("Adding: {0} {1} {2}".format(filePath, img2.shape[0], img2.shape[1]))

        NUMBER_OF_IMG += 1
    
        if result is None:
            result = np.zeros(shape=img2.shape, dtype=np.float32)


        if x % REPEAT_MODE == 0:
            print("REPEATS")
            for n in range(REPEATS):
                r = result
                result = cv2.add(r, img2)
                NUMBER_OF_IMG += 1

        r = result
        result = cv2.add(r, img2)

print("Total images combined: {0}".format(NUMBER_OF_IMG))
r2 = NUMBER_OF_IMG * np.ones(shape=result.shape, dtype=np.float32)
finalResult = cv2.divide(result, r2)
imgPath = outPath2 + "/{0}_f6_189-images.jpg".format("ramsgate_01")
fImg = finalResult.astype(np.uint8)
print(imgPath)
cv2.imwrite(imgPath, fImg)

# !cp $imgPath /content/drive/My\ Drive/Documents/ContactSheet/src/
# Out:
# ################################################################################
# Processing everything in ALL or RAMSGATE_01
# ################################################################################
# inpath: /content/local_drive/concept1_in/ramsgate_01
# outpath: /content/local_drive/concept1_out
# Adding: /content/local_drive/concept1_in/ramsgate_01/IMG_3110.jpg 3024 4032
# REPEATS
# Adding: /content/local_drive/concept1_in/ramsgate_01/IMG_3176.jpg 3024 4032
# Adding: /content/local_drive/concept1_in/ramsgate_01/IMG_3269.jpg 3024 4032
# Adding: /content/local_drive/concept1_in/ramsgate_01/IMG_3232.jpg 3024 4032
# Adding: /content/local_drive/concept1_in/ramsgate_01/IMG_3222.jpg 3024 4032
# Adding: /content/local_drive/concept1_in/ramsgate_01/IMG_3162.jpg 3024 4032
# Adding: /content/local_drive/concept1_in/ramsgate_01/IMG_3092.jpg 3024 4032
# Adding: /content/local_drive/concept1_in/ramsgate_01/IMG_3172.jpg 3024 4032
# ...

# %%
# Concrete Experiment

filePaths = [
             "/content/local_drive/concept1_in/all/_DSC8208.jpg",
             "/content/local_drive/concept1_in/all/_DSC8205.jpg",
             "/content/local_drive/concept1_in/all/_DSC8192.jpg",
             "/content/local_drive/concept1_in/all/_DSC8201.jpg",
             "/content/local_drive/concept1_in/all/_DSC8213.jpg",
            "/content/local_drive/concept1_in/all/_DSC8443.jpg",
             #"/content/local_drive/concept1_in/all/_DSC8457.jpg",
             ]
result = None

WIDTH = 5000
HEIGHT = 3000

for f in filePaths:
    assert os.path.isfile(f)
    print(f)
    img = cv2.imread(f).astype(np.float32)
    #print(img.shape)
    cropped = img[0:HEIGHT, 0:WIDTH]
    rows, cols, x = cropped.shape
    print("Cropped: ", cropped.shape )

    INCREMENTS = 50
    r2 = (INCREMENTS * len(filePaths)) * np.ones(shape=cropped.shape, dtype=np.float32)
    if result is None:
        result = np.zeros(shape=cropped.shape, dtype=np.float32)

    rotationScale = 0.025
    halfTotalRotation = (360 * rotationScale) / 2
    
    print("Rotations")
    for i in range(INCREMENTS):
        #print((360/INCREMENTS) * i)
        #print((cols-1)/2.0)
        rotation = (((360/INCREMENTS) * i) * rotationScale) - halfTotalRotation
        #print(rotation)
        m = cv2.getRotationMatrix2D(((WIDTH/INCREMENTS)*i, (rows-1)/2.0), rotation, 1)
        rotated = cv2.warpAffine(cropped, m, (cols, rows))
        r = result
        #print(r.shape)
        #print(rotated.shape)
        result = cv2.add(r, rotated)



#for i in images:
#    r = result
#    result = cv2.add(r, i)

finalResult = cv2.divide(result, r2)    
imgPath = outPath2 + "/{0}_f6.jpg".format("concrete_experiment_v100")
fImg = finalResult.astype(np.uint8)
print(imgPath)
cv2.imwrite(imgPath, fImg)
# !cp $imgPath /content/drive/My\ Drive/Documents/ContactSheet/src/
# Out:
# /content/local_drive/concept1_in/all/_DSC8208.jpg
# Cropped:  (3000, 5000, 3)
# Rotations
# /content/local_drive/concept1_in/all/_DSC8205.jpg
# Cropped:  (3000, 5000, 3)
# Rotations
# /content/local_drive/concept1_in/all/_DSC8192.jpg
# Cropped:  (3000, 5000, 3)
# Rotations
# /content/local_drive/concept1_in/all/_DSC8201.jpg
# Cropped:  (3000, 5000, 3)
# Rotations
# /content/local_drive/concept1_in/all/_DSC8213.jpg
# Cropped:  (3000, 5000, 3)
# Rotations
# /content/local_drive/concept1_in/all/_DSC8443.jpg
# Cropped:  (3000, 5000, 3)
# Rotations
# /content/local_drive/concept1_out/concrete_experiment_v100_f6.jpg

# %%
# A, B, C
path = r"/content/local_drive/concept1_in"
outPath = path + "fft_1"
outPath2 = r"/content/local_drive/concept1_out"

print("inpath: {0}".format(path))
print("outpath: {0}".format(outPath2))

if os.path.isdir(outPath2):
    pass
else:
    os.makedirs(outPath2)

ROOT_DIR = os.path.abspath(path)
files = os.listdir(path)

images = []
WIDTH = 2500
HEIGHT = 3000

if os.path.isdir(path):
    dirs = os.listdir(path)
    for d in dirs:
        images = []
        dir_path = os.path.join(path, d)
        files = os.listdir(dir_path)
        print(dir_path, " : ", len(files))

        for f in files:
            filePath = os.path.join(dir_path, f)
            img = cv2.imread(filePath)

            if img.shape[0] < HEIGHT:
                continue

            elif img.shape[1] < WIDTH:
                continue

            cropped = img[0:WIDTH, 0:HEIGHT]
            img2 = cropped.astype(np.float32)
            print("Appending: {0} {1} {2}".format(f, img2.shape[0], img2.shape[1]))
            images.append(img2)

        NUMBER_OF_IMG = len(images)
        print("number of img", NUMBER_OF_IMG)
        r2 = NUMBER_OF_IMG * np.ones(shape=[WIDTH, HEIGHT, 3], dtype=np.float32)
        result = np.zeros(shape=[WIDTH, HEIGHT, 3], dtype=np.float32)

        for i in images:    
            print(r2.shape)
            print(result.shape)
            r = result
            print(i.shape)
            print(r.shape)
            result = cv2.add(r, i)

        finalResult = cv2.divide(result, r2)
        imgPath = outPath2 + "/{0}_f6.jpg".format(d)
        fImg = finalResult.astype(np.uint8)
        print(imgPath)
        cv2.imwrite(imgPath, fImg)

        # !cp $imgPath /content/drive/My\ Drive/Documents/ContactSheet/src/
# Out:
# inpath: /content/local_drive/concept1_in
# outpath: /content/local_drive/concept1_out
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d05829c3aa06> in <module>()
#       6 print("outpath: {0}".format(outPath2))
#       7
# ----> 8 if os.path.isdir(outPath2):
#       9     pass
#      10 else:
#
# NameError: name 'os' is not defined
